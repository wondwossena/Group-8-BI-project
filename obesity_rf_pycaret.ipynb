# %%
import pycaret
from pycaret.classification import *
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel(r'C:\Users\Wondwossen\Desktop\BI group 8 project\data\Obesity_Dataset.xlsx', index_col=0)  
df.columns=df.columns.str.strip()
df.head()
# Out:
#      Age  Height  Overweight_Obese_Family  Consumption_of_Fast_Food  \
# Sex
# 2     18     155                        2                         2
# 2     18     158                        2                         2
# 2     18     159                        2                         2
# 2     18     162                        2                         2
# 2     18     165                        2                         1
#
#      Frequency_of_Consuming_Vegetables  Number_of_Main_Meals_Daily  \
# Sex
# 2                                    3                           1
# 2                                    3                           1
# 2                                    2                           1
# 2                                    2                           2
# 2                                    2                           1
#
#      Food_Intake_Between_Meals  Smoking  Liquid_Intake_Daily  \
# Sex
# 2                            3        2                    1
# ...

# %%
df.describe()
# Out:
#                Age       Height  Overweight_Obese_Family  \
# count  1610.000000  1610.000000              1610.000000
# mean     33.115528   167.741615                 1.834783
# std       9.835076     7.979873                 0.371492
# min      18.000000   150.000000                 1.000000
# 25%      25.000000   161.000000                 2.000000
# 50%      32.000000   168.000000                 2.000000
# 75%      41.000000   174.000000                 2.000000
# max      54.000000   193.000000                 2.000000
#
#        Consumption_of_Fast_Food  Frequency_of_Consuming_Vegetables  \
# count               1610.000000                        1610.000000
# mean                   1.729193                           2.063354
# std                    0.444515                           0.746043
# min                    1.000000                           1.000000
# 25%                    1.000000                           2.000000
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Height', 'Overweight_Obese_Family', 'Consumption_of_Fast_Food',
#        'Frequency_of_Consuming_Vegetables', 'Number_of_Main_Meals_Daily',
#        'Food_Intake_Between_Meals', 'Smoking', 'Liquid_Intake_Daily',
#        'Calculation_of_Calorie_Intake', 'Physical_Excercise',
#        'Schedule_Dedicated_to_Technology', 'Type_of_Transportation_Used',
#        'Class'],
#       dtype='object')

# %%
for i in ['Age', 'Height']:
     sns.distplot(df[i])

# %%
sns.distplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
plt.figure(figsize=(5, 4))  
sns.scatterplot(x='Age', y='Height', data=df,hue=df['Class'])  # Specify x and y using parameters and the data  
plt.show()

# %%
plt.figure(figsize=(5, 4))  
sns.violinplot(y=df['Age'],x=df['Class'])
# Out:
# <Axes: xlabel='Class', ylabel='Age'>

# %%
sns.pairplot(df[['Age', 'Height']])

# %%
df.reset_index(drop=True, inplace=True)

# %%
clf = setup(data=df, target='Class')
# Out:
# <style type="text/css">
# #T_1109e_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1109e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1109e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_1109e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1109e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1109e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_1109e_row0_col1" class="data row0 col1" >4626</td>
#     </tr>
#     <tr>
#       <th id="T_1109e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1109e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_1109e_row1_col1" class="data row1 col1" >Class</td>
#     </tr>
#     <tr>
#       <th id="T_1109e_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# lightgbm  Light Gradient Boosting Machine
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# ...

# %%
rf=create_model('rf')
# Out:
# <style type="text/css">
# #T_fd5c2_row10_col0, #T_fd5c2_row10_col1, #T_fd5c2_row10_col2, #T_fd5c2_row10_col3, #T_fd5c2_row10_col4, #T_fd5c2_row10_col5, #T_fd5c2_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_fd5c2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd5c2_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_fd5c2_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_fd5c2_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_fd5c2_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_fd5c2_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_fd5c2_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_fd5c2_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
evaluate_model(rf)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
save_model(rf,'obesity_rf')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Age', 'Height',
#                                               'Overweight_Obese_Family',
#                                               'Consumption_of_Fast_Food',
#                                               'Frequency_of_Consuming_Vegetables',
#                                               'Number_of_Main_Meals_Daily',
#                                               'Food_I...
#                   RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                          class_weight=None, criterion='gini',
# ...

# %%
plot_model(rf,'feature')

# %%
importance_df = pull()  

# Step 5: Inspect the DataFrame and print columns to understand structure  
print(importance_df)  

# Depending on the model and type of output, the correct column name may differ.  
# Let's check what columns are present.  
print(importance_df.columns)  

# Step 6: Sort the DataFrame by the correct column name for importance  
# Note: Adjust the column name based on what you find in the output of importance_df.columns  
# Example column name could be 'Feature' and 'Score' based on the model used.  
if 'Feature' in importance_df.columns and 'Score' in importance_df.columns:  
    importance_df = importance_df.sort_values(by='Score', ascending=False)  

# Step 7: Display feature importances  
print(importance_df)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.8584  0.9435  0.8584  0.8657  0.8557  0.7812  0.7843
# 1       0.8496  0.9306  0.8496  0.8506  0.8479  0.7707  0.7722
# 2       0.8496  0.9580  0.8496  0.8504  0.8487  0.7705  0.7712
# 3       0.8496  0.9266  0.8496  0.8529  0.8500  0.7705  0.7712
# 4       0.7788  0.9221  0.7788  0.7841  0.7748  0.6673  0.6726
# 5       0.8230  0.9696  0.8230  0.8204  0.8209  0.7318  0.7322
# 6       0.8761  0.9554  0.8761  0.8898  0.8755  0.8109  0.8158
# 7       0.8661  0.9513  0.8661  0.8711  0.8648  0.7944  0.7958
# 8       0.8214  0.9416  0.8214  0.8288  0.8128  0.7259  0.7272
# 9       0.8393  0.9652  0.8393  0.8385  0.8384  0.7562  0.7566
# Mean    0.8412  0.9464  0.8412  0.8452  0.8389  0.7579  0.7599
# Std     0.0264  0.0155  0.0264  0.0280  0.0278  0.0388  0.0386
# Index(['Accuracy', 'AUC', 'Recall', 'Prec.', 'F1', 'Kappa', 'MCC'], dtype='object')
# ...
